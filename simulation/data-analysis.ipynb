# %%
import numpy as np

# %%
run simulate_data.py
# Out:
# Attempting to import the Seaborn module...Success!
# Simulating... Done!
# Saving data... Done!
# Saving plot... Done!

# %%
monte_carlo = np.loadtxt('simulation_data.csv',dtype=np.double,skiprows=1, delimiter=',')
dynamical = np.loadtxt('poplevels.csv',dtype=np.double,delimiter=',')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(dynamical[:,0])
plt.plot(monte_carlo[:,0])

# %%
print(np.shape(dynamical[:,0]),np.shape(monte_carlo[:,0]))
# Out:
# (101,) (100,)

# %%
dynamical[:,0]
# Out:
# array([ 0.4    ,  0.62757,  0.7187 ,  0.74279,  0.74837,  0.74964,
#         0.74992,  0.74998,  0.75   ,  0.75   ,  0.75   ,  0.75   ,
#         0.75003,  0.74999,  0.75   ,  0.75   ,  0.75   ,  0.75   ,
#         0.75   ,  0.75001,  0.74999,  0.75003,  0.74998,  0.75001,
#         0.75002,  0.74997,  0.75001,  0.74999,  0.75   ,  0.75   ,
#         0.75   ,  0.75   ,  0.75002,  0.74998,  0.75003,  0.75002,
#         0.74996,  0.75003,  0.74996,  0.75   ,  0.74999,  0.75   ,
#         0.75   ,  0.75001,  0.74999,  0.75003,  0.75001,  0.74997,
#         0.75005,  0.74995,  0.75001,  0.74998,  0.75   ,  0.74999,
#         0.75001,  0.74999,  0.75002,  0.75   ,  0.75   ,  0.75005,
#         0.74995,  0.75002,  0.74998,  0.75   ,  0.74999,  0.75   ,
#         0.74999,  0.75001,  0.75   ,  0.75001,  0.75003,  0.74996,
#         0.75004,  0.74999,  0.74999,  0.74999,  0.75   ,  0.74999,
#         0.75001,  0.75   ,  0.75001,  0.75002,  0.74998,  0.75006,
# ...

# %%
monte_carlo[:,0]
# Out:
# array([ 0.4 ,  0.4 ,  0.64,  0.69,  0.69,  0.69,  0.74,  0.73,  0.67,
#         0.73,  0.73,  0.73,  0.71,  0.72,  0.71,  0.71,  0.71,  0.69,
#         0.68,  0.71,  0.63,  0.65,  0.7 ,  0.7 ,  0.67,  0.67,  0.73,
#         0.66,  0.7 ,  0.68,  0.68,  0.7 ,  0.73,  0.71,  0.67,  0.69,
#         0.7 ,  0.71,  0.67,  0.75,  0.72,  0.71,  0.71,  0.75,  0.73,
#         0.73,  0.71,  0.74,  0.71,  0.69,  0.69,  0.7 ,  0.7 ,  0.7 ,
#         0.7 ,  0.71,  0.73,  0.72,  0.69,  0.75,  0.74,  0.72,  0.72,
#         0.71,  0.66,  0.68,  0.68,  0.75,  0.71,  0.72,  0.7 ,  0.68,
#         0.7 ,  0.69,  0.72,  0.71,  0.71,  0.69,  0.7 ,  0.72,  0.7 ,
#         0.73,  0.73,  0.7 ,  0.73,  0.67,  0.71,  0.66,  0.7 ,  0.68,
#         0.7 ,  0.69,  0.72,  0.69,  0.69,  0.71,  0.66,  0.72,  0.74,
#         0.73,  0.7 ])
